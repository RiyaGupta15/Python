# %%
import pandas as pd

# %%
df = pd.read_csv('appointment.csv')

# %%
df
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 0      2.990000e+13        5642903      F  2016-04-29T18:38:08Z
# 1      5.590000e+14        5642503      M  2016-04-29T16:08:27Z
# 2      4.260000e+12        5642549      F  2016-04-29T16:19:04Z
# 3      8.680000e+11        5642828      F  2016-04-29T17:29:31Z
# 4      8.840000e+12        5642494      F  2016-04-29T16:07:23Z
# ...             ...            ...    ...                   ...
# 32392  6.640000e+11        5647547      F  2016-05-02T13:51:56Z
# 32393  3.740000e+13        5661968      M  2016-05-05T07:57:59Z
# 32394  9.960000e+12        5688887      F  2016-05-12T07:45:40Z
# 32395  6.650000e+12        5713273      F  2016-05-18T09:56:02Z
# 32396  4.140000e+13        5644851      M  2016-05-02T09:10:58Z
#
#              AppointmentDay  Age      Neighbourhood  SMS_received No-show  \
# 0      2016-04-29T00:00:00Z   62    JARDIM DA PENHA             0      No
# ...

# %%
df.shape
# Out:
# (32397, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32397 entries, 0 to 32396
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   PatientId                             32397 non-null  float64
#  1   AppointmentID                         32397 non-null  int64
#  2   Gender                                32397 non-null  object
#  3   ScheduledDay                          32397 non-null  object
#  4   AppointmentDay                        32397 non-null  object
#  5   Age                                   32397 non-null  int64
#  6   Neighbourhood                         32397 non-null  object
#  7   SMS_received                          32397 non-null  int64
#  8   No-show                               32397 non-null  object
#  9   PRIORITY_TYPE_CODE                    32073 non-null  float64
#  10  Index of Multiple Deprivation Decile  31563 non-null  float64
# ...

# %%
## To make all the columns of the dataset visible
pd.set_option('display.max_columns', 16)

## To make all the rows of the dataset visible
pd.set_option('display.max_rows', 32397)

# %%
## To get the first five rows of dataset
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.990000e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.590000e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.260000e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.680000e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.840000e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  SMS_received No-show  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA             0      No
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA             0      No
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA             0      No
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI             0      No
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA             0      No
#
#    PRIORITY_TYPE_CODE  Index of Multiple Deprivation Decile  Income Decile  \
# 0                 1.0                                  10.0            9.0
# ...

# %%
## To get the first ten rows of dataset
df.head(10)
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.990000e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.590000e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.260000e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.680000e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.840000e+12        5642494      F  2016-04-29T16:07:23Z
# 5  9.600000e+13        5626772      F  2016-04-27T08:36:51Z
# 6  7.340000e+14        5630279      F  2016-04-27T15:05:12Z
# 7  3.450000e+12        5630575      F  2016-04-27T15:39:58Z
# 8  5.640000e+13        5638447      F  2016-04-29T08:02:16Z
# 9  7.810000e+13        5629123      F  2016-04-27T12:48:25Z
#
#          AppointmentDay  Age      Neighbourhood  SMS_received No-show  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA             0      No
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA             0      No
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA             0      No
# ...

# %%
## To get the last five rows of dataset
df.tail()
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 32392  6.640000e+11        5647547      F  2016-05-02T13:51:56Z
# 32393  3.740000e+13        5661968      M  2016-05-05T07:57:59Z
# 32394  9.960000e+12        5688887      F  2016-05-12T07:45:40Z
# 32395  6.650000e+12        5713273      F  2016-05-18T09:56:02Z
# 32396  4.140000e+13        5644851      M  2016-05-02T09:10:58Z
#
#              AppointmentDay  Age   Neighbourhood  SMS_received No-show  \
# 32392  2016-05-19T00:00:00Z   28  PARQUE MOSCOSO             0     Yes
# 32393  2016-05-05T00:00:00Z    2      CONSOLAÇÃO             0      No
# 32394  2016-05-12T00:00:00Z   31          CENTRO             0      No
# 32395  2016-05-19T00:00:00Z   59  PARQUE MOSCOSO             0      No
# 32396  2016-05-05T00:00:00Z   54  PARQUE MOSCOSO             0      No
#
#        PRIORITY_TYPE_CODE  Index of Multiple Deprivation Decile  \
# 32392                 1.0                                   7.0
# ...

# %%
## To get the last ten rows of dataset
df.tail(10)
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 32387  5.940000e+12        5678059      M  2016-05-10T08:00:55Z
# 32388  6.620000e+12        5717106      F  2016-05-19T07:33:06Z
# 32389  6.520000e+14        5713819      M  2016-05-18T10:46:04Z
# 32390  6.170000e+13        5647423      F  2016-05-02T13:35:20Z
# 32391  6.660000e+13        5647523      M  2016-05-02T13:48:13Z
# 32392  6.640000e+11        5647547      F  2016-05-02T13:51:56Z
# 32393  3.740000e+13        5661968      M  2016-05-05T07:57:59Z
# 32394  9.960000e+12        5688887      F  2016-05-12T07:45:40Z
# 32395  6.650000e+12        5713273      F  2016-05-18T09:56:02Z
# 32396  4.140000e+13        5644851      M  2016-05-02T09:10:58Z
#
#              AppointmentDay  Age   Neighbourhood  SMS_received No-show  \
# 32387  2016-05-12T00:00:00Z    5      DO MOSCOSO             0      No
# 32388  2016-05-19T00:00:00Z   53          CENTRO             0      No
# ...
